# %%
# Import library yang diperlukan
import argparse
import getpass
import imaplib
import poplib
import smtplib

# %%
IMAP_SERVER = 'outlook.office365.com'
IMAP_PORT = 993

POP_SERVER = 'outlook.office365.com'
POP_PORT = 995
def imap_mail(username):
    # Tulis kode program dari sini
    mailbox = imaplib.IMAP4_SSL(IMAP_SERVER, IMAP_PORT) 
    password = getpass.getpass(prompt='Enter your email password: ') 
    mailbox.login(username, password)
    mailbox.select('Inbox')
    typ, data = mailbox.search(None, 'ALL')
    for num in data[0].split():
        typ, data = mailbox.fetch(num, '(RFC822)')
        print ('Message %s\n%s\n' % (num, data[0][1]))
        break
    mailbox.close()
    mailbox.logout()
        # Implementasikan Error-handling 
    
    # Sampai di sini
    
def pop_mail(username):
    # Tulis kode program dari sini 
    mailbox = poplib.POP3_SSL(POP_SERVER, POP_PORT) 
    mailbox.user(username)
    password = getpass.getpass(prompt='Enter your email password: ') 
    mailbox.pass_(password) 
    num_messages = len(mailbox.list()[1])
    print ('Total emails: {}'.format(num_messages))
    mailbox.quit()
        # Implementasikan Error-handling
        
    # Sampai di sini

# %% [markdown]
# Buatlah sebuah fungsi yang dapat menggabungkan fungsionalitas fungsi `imap_mail()` dan `pop_mail()`

# %%
def mail(username, protocol, host, port):
    # Tulis kode program dari sini 
    imap_mail('170010169@stikom-bali.ac.id')
    pop_mail('170010169@stikom-bali.ac.id')    
        # Implementasikan Error-handling
  
    # Sampai di sini

# %% [markdown]
# Panggil fungsi `mail()` di bawah ini:

# %%
if __name__ == '__main__':
    mail('username','','','')
# Out:
# Enter your email password: ········
# Message b'1'
# b'Received: from TY2PR06MB2637.apcprd06.prod.outlook.com (2603:1096:404:a6::25)\r\n by TY2PR06MB2592.apcprd06.prod.outlook.com with HTTPS via\r\n TY2PR02CA0037.APCPRD02.PROD.OUTLOOK.COM; Thu, 19 Mar 2020 03:14:14 +0000\r\nARC-Seal: i=2; a=rsa-sha256; s=arcselector9901; d=microsoft.com; cv=pass;\r\n b=\r\nARC-Message-Signature: i=2; a=rsa-sha256; c=relaxed/relaxed; d=microsoft.com;\r\n s=arcselector9901;\r\n h=From:Date:Subject:Message-ID:Content-Type:MIME-Version:X-MS-Exchange-SenderADCheck;\r\n bh=6kA82PiLQxel+hIH0Dk8bMKhG3s0jTnJMHl+FinI77Q=;\r\n b=\r\nARC-Authentication-Results: i=2; mx.microsoft.com 1; spf=pass (sender ip is\r\n 40.107.237.79) smtp.rcpttodomain=stikom-bali.ac.id\r\n smtp.mailfrom=email.teams.microsoft.com; dmarc=pass (p=reject sp=reject\r\n pct=100) action=none header.from=email.teams.microsoft.com; dkim=pass\r\n (signature was verified) header.d=email.teams.microsoft.com; arc=pass (0\r\n oda=1 ltdi=1 spf=[1,1,smtp.mailfrom=email.teams.microsoft.com]\r\n dmarc=[1,1,header.from=email.teams.microsoft.com])\r\nReceived: from SL2P216CA0013.KORP216.PROD.OUTLOOK.COM (2603:1096:100:18::23)\r\n by TY2PR06MB2637.apcprd06.prod.outlook.com (2603:1096:404:3c::15) with\r\n Microsoft SMTP Server (version=TLS1_2,\r\n cipher=TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384) id 15.20.2814.21; Thu, 19 Mar\r\n 2020 03:14:12 +0000\r\nReceived: from PU1APC01FT063.eop-APC01.prod.protection.outlook.com\r\n (2603:1096:100:18:cafe::fc) by SL2P216CA0013.outlook.office365.com\r\n (2603:1096:100:18::23) with Microsoft SMTP Server (version=TLS1_2,\r\n cipher=TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384) id 15.20.2835.18 via Frontend\r\n Transport; Thu, 19 Mar 2020 03:14:11 +0000\r\nAuthentication-Results: spf=pass (sender IP is 40.107.237.79)\r\n smtp.mailfrom=email.teams.microsoft.com; stikom-bali.ac.id; dkim=pass\r\n (signature was verified)\r\n header.d=email.teams.microsoft.com;stikom-bali.ac.id; dmarc=pass action=none\r\n header.from=email.teams.microsoft.com;compauth=pass reason=100\r\nReceived-SPF: Pass (protection.outlook.com: domain of\r\n email.teams.microsoft.com designates 40.107.237.79 as permitted sender)\r\n receiver=protection.outlook.com; client-ip=40.107.237.79;\r\n helo=NAM12-BN8-obe.outbound.protection.outlook.com;\r\nReceived: from NAM12-BN8-obe.outbound.protection.outlook.com (40.107.237.79)\r\n by PU1APC01FT063.mail.protection.outlook.com (10.152.253.40) with Microsoft\r\n SMTP Server (version=TLS1_2, cipher=TLS_ECDHE_RSA_WITH_AES_256_GCM_SHA384) id\r\n 15.20.2814.13 via Frontend Transport; Thu, 19 Mar 2020 03:14:10 +0000\r\nARC-Seal: i=1; a=rsa-sha256; s=arcselector9901; d=microsoft.com; cv=none;\r\n b=\r\nARC-Message-Signature: i=1; a=rsa-sha256; c=relaxed/relaxed; d=microsoft.com;\r\n s=arcselector9901;\r\n h=From:Date:Subject:Message-ID:Content-Type:MIME-Version:X-MS-Exchange-SenderADCheck;\r\n bh=6kA82PiLQxel+hIH0Dk8bMKhG3s0jTnJMHl+FinI77Q=;\r\n b=nyGz4O17NWA2QQWfpPVYnpx2JuTbWuooa8T4uK4QPHRCztBZCsxBn8ySVnvnPiw0G+Y ...
# Enter your email password: ········
# Total emails: 8
